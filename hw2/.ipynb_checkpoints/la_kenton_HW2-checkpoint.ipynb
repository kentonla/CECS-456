# %%
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\kento\appdata\roaming\python\python313\site-packages (2.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # **HW 2: Decision Trees and Overfitting**
# **HW Due date is 03/04/2024, 1:59 pm**
#
# Objective:
# * To understand the basics of decision trees and Hunt's algorithm.
# * To practice building decision trees using sample datasets.
# * To visualize model performance and apply pre-pruning and post-pruning techniques to tackle overfitting issues.

# %%
# Import the neccesary libraries
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Creating a Dataset:
# Two class problem:
#
# 1400 instances of blue class
# * 1000 instances generated from a Gaussian centered at (10,10)
# * 400 noisy instances added
#
# 1400 instances of green class
# * Generated from a uniform distribution in (0,20) coordinates

# %%
# Set random seed for reproducibility
np.random.seed(42)

# Generate instances for class one using normal distribution
class_one_mean = (10, 10)  # Center around (10, 10)
class_one_std = 1
class_one_instances = 1000
class_one = np.random.normal(loc=class_one_mean, scale=class_one_std, size=(class_one_instances, 2))

# Generate noisy instances for class one
noisy_instances = 400
class_one_noisy = np.random.normal(loc=(0, 0), scale=3, size=(noisy_instances, 2))

# Generate instances for class two using uniform distribution in a [0,20] range]
class_two_instances = 1400
class_two = np.random.uniform(low=0, high=20, size=(class_two_instances, 2))

# Concatenate class one instances and noisy instances
X_class_one = np.vstack((class_one, class_one_noisy + class_one_mean))  # Adjusting mean to add noise
y_class_one = np.zeros(X_class_one.shape[0])  # Label for class one is 0

# Labels for class two are 1
X_class_two = class_two
y_class_two = np.ones(class_two.shape[0])

# Concatenate features and labels for both classes
X = np.vstack((X_class_one, X_class_two))
y = np.concatenate((y_class_one, y_class_two))


# Visualize the data
plt.figure(figsize=(10, 6))

# Plot instances for class one
plt.scatter(X_class_one[:, 0], X_class_one[:, 1], color='blue', label='Class One (Normal)', alpha=0.5)

# Plot instances for class two
plt.scatter(X_class_two[:, 0], X_class_two[:, 1], color='green', label='Class Two (Uniform)', alpha=0.5)

plt.title('Generated Dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The default values for the DecisionTreeClassifier in scikit-learn are as follows:
#
# **criterion:** The function to measure the quality of a split. By default, it is set to 'gini', which measures the impurity of the split based on the Gini impurity criterion. Alternatively, you can set it to 'entropy' to use information gain.
#
# **splitter:** The strategy used to choose the split at each node. By default, it is set to 'best', which chooses the best split. Alternatively, you can set it to 'random' to choose the best random split.
#
# **max_depth:** The maximum depth of the tree. By default, it is set to 'None', meaning nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
#
# **min_samples_split:** The minimum number of samples required to split an internal node. By default, it is set to 2, meaning nodes with fewer than 2 samples are not split further.
#
# **min_samples_leaf:** The minimum number of samples required to be at a leaf node. By default, it is set to 1, meaning nodes will continue to be split until each leaf node contains 1 sample.
#
# **max_features:** The number of features to consider when looking for the best split. By default, it is set to 'None', meaning all features are considered.
# random_state: The seed of the random number generator. By default, it is set to 'None'.
#
# **max_leaf_nodes:** The maximum number of leaf nodes in the tree. By default, it is set to 'None', meaning unlimited number of leaf nodes.
#
# **min_impurity_decrease:** A node will be split if this split induces a decrease of the impurity greater than or equal to this value. By default, it is set to 0.0.
#
# **ccp_alpha:** Complexity parameter used for Minimal Cost-Complexity Pruning. By default, it is set to 0.0.
#
# These are the primary parameters, but there are others as well, and you can refer to the scikit-learn documentation for more details.

# %% [markdown]
# **Coding Exersice:** Train a decisoin tree with default parameters from DecisionTreeClassifier in sklearn library. Show the accuracy results for both training and test sets.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split the dataset into training and testing sets with 20% test and 80% training
#You code starts here
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.20, train_size=0.80, random_state=42)
#Your code ends here

# Train a decision tree classifier with default parameters
#You code starts here
clf = DecisionTreeClassifier(random_state=42)
clf.fit(x_train, y_train)
#Your code ends here

# Evaluate the classifier on the training set
#You code starts here
y_train_pred = clf.predict(x_train)
accuracy_score(y_train, y_train_pred)
#Your code ends here

# Evaluate the classifier on the testing set
#You code starts here
y_test_pred = clf.predict(x_test)
accuracy_score(y_test, y_test_pred)
#Your code ends here


# Visualize the learned tree
""" use plot_tree from sklearn.tree """
#You code starts here
plot_tree(clf)
#Your code ends here
# Out:
# [Text(0.6471089446156874, 0.98, 'x[0] <= 12.72\ngini = 0.5\nsamples = 2240\nvalue = [1109, 1131]'),
#  Text(0.3536027265870934, 0.94, 'x[0] <= 7.907\ngini = 0.483\nsamples = 1798\nvalue = [1066, 732]'),
#  Text(0.5003558356013904, 0.96, 'True  '),
#  Text(0.08689664218258132, 0.9, 'x[0] <= 5.177\ngini = 0.259\nsamples = 530\nvalue = [81, 449]'),
#  Text(0.025183630640083946, 0.86, 'x[1] <= 7.16\ngini = 0.065\nsamples = 298\nvalue = [10, 288]'),
#  Text(0.02098635886673662, 0.82, 'gini = 0.0\nsamples = 99\nvalue = [0, 99]'),
#  Text(0.02938090241343127, 0.82, 'x[1] <= 7.218\ngini = 0.095\nsamples = 199\nvalue = [10, 189]'),
#  Text(0.025183630640083946, 0.78, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.033578174186778595, 0.78, 'x[1] <= 14.644\ngini = 0.087\nsamples = 198\nvalue = [9, 189]'),
#  Text(0.02938090241343127, 0.74, 'x[1] <= 14.505\ngini = 0.149\nsamples = 111\nvalue = [9, 102]'),
#  Text(0.025183630640083946, 0.7, 'x[0] <= 4.295\ngini = 0.135\nsamples = 110\nvalue = [8, 102]'),
#  Text(0.016789087093389297, 0.66, 'x[1] <= 9.056\ngini = 0.102\nsamples = 93\nvalue = [5, 88]'),
#  Text(0.012591815320041973, 0.62, 'gini = 0.0\nsamples = 28\nvalue = [0, 28]'),
#  Text(0.02098635886673662, 0.62, 'x[1] <= 9.111\ngini = 0.142\nsamples = 65\nvalue = [5, 60]'),
#  Text(0.016789087093389297, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.025183630640083946, 0.58, 'x[1] <= 10.711\ngini = 0.117\nsamples = 64\nvalue = [4, 60]'),
#  Text(0.016789087093389297, 0.54, 'x[1] <= 10.461\ngini = 0.266\nsamples = 19\nvalue = [3, 16]'),
#  Text(0.012591815320041973, 0.5, 'x[1] <= 9.43\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.008394543546694649, 0.46, 'x[1] <= 9.404\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.004197271773347324, 0.42, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.012591815320041973, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.016789087093389297, 0.46, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.02098635886673662, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.033578174186778595, 0.54, 'x[0] <= 3.518\ngini = 0.043\nsamples = 45\nvalue = [1, 44]'),
#  Text(0.02938090241343127, 0.5, 'gini = 0.0\nsamples = 40\nvalue = [0, 40]'),
#  Text(0.03777544596012592, 0.5, 'x[0] <= 3.623\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.033578174186778595, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04197271773347324, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.033578174186778595, 0.66, 'x[0] <= 4.39\ngini = 0.291\nsamples = 17\nvalue = [3, 14]'),
#  Text(0.02938090241343127, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03777544596012592, 0.62, 'x[1] <= 7.977\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.033578174186778595, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04197271773347324, 0.58, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.033578174186778595, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03777544596012592, 0.74, 'gini = 0.0\nsamples = 87\nvalue = [0, 87]'),
#  Text(0.1486096537250787, 0.86, 'x[1] <= 14.95\ngini = 0.425\nsamples = 232\nvalue = [71, 161]'),
#  Text(0.10939139559286463, 0.82, 'x[1] <= 5.59\ngini = 0.467\nsamples = 188\nvalue = [70, 118]'),
#  Text(0.0776495278069255, 0.78, 'x[0] <= 5.257\ngini = 0.08\nsamples = 48\nvalue = [2, 46]'),
#  Text(0.06925498426023086, 0.74, 'x[0] <= 5.23\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06505771248688352, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07345225603357818, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08604407135362015, 0.74, 'x[1] <= 4.074\ngini = 0.043\nsamples = 45\nvalue = [1, 44]'),
#  Text(0.08184679958027283, 0.7, 'gini = 0.0\nsamples = 33\nvalue = [0, 33]'),
#  Text(0.09024134312696747, 0.7, 'x[1] <= 4.131\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.08604407135362015, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0944386149003148, 0.66, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.14113326337880377, 0.78, 'x[0] <= 7.223\ngini = 0.5\nsamples = 140\nvalue = [68, 72]'),
#  Text(0.10283315844700944, 0.74, 'x[0] <= 5.214\ngini = 0.474\nsamples = 96\nvalue = [37, 59]'),
#  Text(0.09863588667366212, 0.7, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.10703043022035677, 0.7, 'x[1] <= 6.074\ngini = 0.464\nsamples = 93\nvalue = [34, 59]'),
#  Text(0.10283315844700944, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.11122770199370409, 0.66, 'x[1] <= 12.683\ngini = 0.452\nsamples = 90\nvalue = [31, 59]'),
#  Text(0.08814270724029381, 0.62, 'x[1] <= 11.351\ngini = 0.48\nsamples = 65\nvalue = [26, 39]'),
#  Text(0.06715634837355719, 0.58, 'x[1] <= 10.322\ngini = 0.42\nsamples = 50\nvalue = [15, 35]'),
#  Text(0.05876180482686254, 0.54, 'x[0] <= 6.987\ngini = 0.47\nsamples = 37\nvalue = [14, 23]'),
#  Text(0.05456453305351522, 0.5, 'x[0] <= 6.893\ngini = 0.492\nsamples = 32\nvalue = [14, 18]'),
#  Text(0.05036726128016789, 0.46, 'x[0] <= 6.772\ngini = 0.48\nsamples = 30\nvalue = [12, 18]'),
#  Text(0.046169989506820566, 0.42, 'x[0] <= 6.706\ngini = 0.494\nsamples = 27\nvalue = [12, 15]'),
#  Text(0.04197271773347324, 0.38, 'x[0] <= 6.498\ngini = 0.454\nsamples = 23\nvalue = [8, 15]'),
#  Text(0.02728226652675761, 0.34, 'x[1] <= 7.956\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.01888772298006296, 0.3, 'x[0] <= 6.39\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.014690451206715634, 0.26, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.023084994753410283, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.035676810073452254, 0.3, 'x[0] <= 5.391\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.03147953830010493, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03987408184679958, 0.26, 'x[1] <= 9.478\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.035676810073452254, 0.22, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.04407135362014691, 0.22, 'x[0] <= 5.56\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.03987408184679958, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.048268625393494226, 0.18, 'x[1] <= 10.015\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.04407135362014691, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05246589716684155, 0.14, 'x[1] <= 10.116\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.048268625393494226, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05666316894018888, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05666316894018888, 0.34, 'x[1] <= 7.345\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.05246589716684155, 0.3, 'x[1] <= 7.12\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.048268625393494226, 0.26, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05666316894018888, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.060860440713536204, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.05036726128016789, 0.38, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.05456453305351522, 0.42, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.05876180482686254, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06295907660020986, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.07555089192025184, 0.54, 'x[0] <= 6.892\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.07135362014690451, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.07974816369359916, 0.5, 'x[1] <= 11.104\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07555089192025184, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08394543546694648, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10912906610703044, 0.58, 'x[1] <= 12.233\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.10073452256033578, 0.54, 'x[0] <= 5.846\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.09653725078698845, 0.5, 'x[0] <= 5.557\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09233997901364113, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10073452256033578, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1049317943336831, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.11752360965372508, 0.54, 'x[1] <= 12.378\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.11332633788037776, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12172088142707241, 0.5, 'x[1] <= 12.552\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.11752360965372508, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1259181532004197, 0.46, 'x[0] <= 6.214\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12172088142707241, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13011542497376705, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13431269674711438, 0.62, 'x[1] <= 14.773\ngini = 0.32\nsamples = 25\nvalue = [5, 20]'),
#  Text(0.13011542497376705, 0.58, 'x[1] <= 13.307\ngini = 0.278\nsamples = 24\nvalue = [4, 20]'),
#  Text(0.1259181532004197, 0.54, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.13431269674711438, 0.54, 'x[1] <= 13.392\ngini = 0.391\nsamples = 15\nvalue = [4, 11]'),
#  Text(0.13011542497376705, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1385099685204617, 0.5, 'x[0] <= 6.647\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.13431269674711438, 0.46, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.14270724029380902, 0.46, 'x[1] <= 14.449\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.1385099685204617, 0.42, 'x[0] <= 6.964\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.13431269674711438, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.14270724029380902, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14690451206715635, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1385099685204617, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1794333683105981, 0.74, 'x[1] <= 8.926\ngini = 0.416\nsamples = 44\nvalue = [31, 13]'),
#  Text(0.155299055613851, 0.7, 'x[0] <= 7.324\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(0.15110178384050368, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15949632738719832, 0.66, 'x[0] <= 7.557\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.15110178384050368, 0.62, 'x[1] <= 7.955\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.14690451206715635, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.155299055613851, 0.58, 'x[0] <= 7.502\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.15110178384050368, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15949632738719832, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16789087093389296, 0.62, 'x[1] <= 5.941\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.16369359916054566, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1720881427072403, 0.58, 'x[1] <= 8.395\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.16789087093389296, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.17628541448058763, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20356768100734524, 0.7, 'x[0] <= 7.86\ngini = 0.32\nsamples = 30\nvalue = [24, 6]'),
#  Text(0.1930745015739769, 0.66, 'x[0] <= 7.297\ngini = 0.252\nsamples = 27\nvalue = [23, 4]'),
#  Text(0.18467995802728226, 0.62, 'x[0] <= 7.23\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.18048268625393493, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1888772298006296, 0.58, 'x[1] <= 13.689\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.18467995802728226, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1930745015739769, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20146904512067157, 0.62, 'x[1] <= 11.093\ngini = 0.159\nsamples = 23\nvalue = [21, 2]'),
#  Text(0.19727177334732424, 0.58, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.20566631689401887, 0.58, 'x[1] <= 11.331\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.20146904512067157, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2098635886673662, 0.54, 'x[1] <= 12.359\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.20566631689401887, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.21406086044071354, 0.5, 'x[1] <= 12.895\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.2098635886673662, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21825813221406087, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21406086044071354, 0.66, 'x[0] <= 7.876\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2098635886673662, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.21825813221406087, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.18782791185729275, 0.82, 'x[0] <= 7.493\ngini = 0.044\nsamples = 44\nvalue = [1, 43]'),
#  Text(0.18363064008394545, 0.78, 'gini = 0.0\nsamples = 36\nvalue = [0, 36]'),
#  Text(0.19202518363064008, 0.78, 'x[0] <= 7.507\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.18782791185729275, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19622245540398742, 0.74, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6203088109916055, 0.9, 'x[1] <= 14.485\ngini = 0.347\nsamples = 1268\nvalue = [985.0, 283.0]'),
#  Text(0.43788939533053517, 0.86, 'x[1] <= 6.972\ngini = 0.283\nsamples = 1180\nvalue = [979, 201]'),
#  Text(0.2838405036726128, 0.82, 'x[1] <= 5.067\ngini = 0.375\nsamples = 140\nvalue = [35, 105]'),
#  Text(0.24239244491080797, 0.78, 'x[1] <= 3.243\ngini = 0.178\nsamples = 81\nvalue = [8, 73]'),
#  Text(0.23819517313746066, 0.74, 'gini = 0.0\nsamples = 44\nvalue = [0, 44]'),
#  Text(0.2465897166841553, 0.74, 'x[1] <= 3.4\ngini = 0.339\nsamples = 37\nvalue = [8, 29]'),
#  Text(0.23504721930745015, 0.7, 'x[1] <= 3.336\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.23084994753410285, 0.66, 'x[1] <= 3.295\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2266526757607555, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.23504721930745015, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23924449108079748, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.25813221406086045, 0.7, 'x[0] <= 9.207\ngini = 0.257\nsamples = 33\nvalue = [5, 28]'),
#  Text(0.24763903462749212, 0.66, 'x[0] <= 8.309\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.24344176285414482, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2518363064008394, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.26862539349422876, 0.66, 'x[1] <= 4.635\ngini = 0.191\nsamples = 28\nvalue = [3, 25]'),
#  Text(0.2602308499475341, 0.62, 'x[1] <= 3.716\ngini = 0.1\nsamples = 19\nvalue = [1, 18]'),
#  Text(0.25603357817418676, 0.58, 'x[1] <= 3.658\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2518363064008394, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.2602308499475341, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2644281217208814, 0.58, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.2770199370409234, 0.62, 'x[1] <= 4.712\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.2728226652675761, 0.58, 'x[1] <= 4.659\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.26862539349422876, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2770199370409234, 0.54, 'x[0] <= 10.405\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2728226652675761, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2812172088142707, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2812172088142707, 0.58, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3252885624344176, 0.78, 'x[0] <= 11.377\ngini = 0.496\nsamples = 59\nvalue = [27, 32]'),
#  Text(0.30640083945435465, 0.74, 'x[1] <= 5.369\ngini = 0.433\nsamples = 41\nvalue = [13.0, 28.0]'),
#  Text(0.2938090241343127, 0.7, 'x[0] <= 9.163\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.28961175236096537, 0.66, 'x[0] <= 8.501\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.28541448058761804, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2938090241343127, 0.62, 'x[0] <= 8.773\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.28961175236096537, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.29800629590766003, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.29800629590766003, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.31899265477439664, 0.7, 'x[1] <= 6.731\ngini = 0.382\nsamples = 35\nvalue = [9, 26]'),
#  Text(0.3147953830010493, 0.66, 'x[1] <= 6.69\ngini = 0.42\nsamples = 30\nvalue = [9, 21]'),
#  Text(0.310598111227702, 0.62, 'x[1] <= 5.593\ngini = 0.4\nsamples = 29\nvalue = [8, 21]'),
#  Text(0.30640083945435465, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.3147953830010493, 0.58, 'x[1] <= 5.69\ngini = 0.435\nsamples = 25\nvalue = [8, 17]'),
#  Text(0.310598111227702, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.31899265477439664, 0.54, 'x[0] <= 11.142\ngini = 0.386\nsamples = 23\nvalue = [6, 17]'),
#  Text(0.3147953830010493, 0.5, 'x[0] <= 9.052\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.30640083945435465, 0.46, 'x[0] <= 8.822\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.30220356768100737, 0.42, 'x[1] <= 6.273\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.29800629590766003, 0.38, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.30640083945435465, 0.38, 'x[1] <= 6.483\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.30220356768100737, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.310598111227702, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.310598111227702, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.323189926547744, 0.46, 'x[0] <= 10.677\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(0.31899265477439664, 0.42, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.3273871983210913, 0.42, 'x[0] <= 10.917\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.323189926547744, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3315844700944386, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.323189926547744, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.31899265477439664, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.323189926547744, 0.66, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3441762854144806, 0.74, 'x[1] <= 5.643\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(0.3357817418677859, 0.7, 'x[0] <= 11.667\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3315844700944386, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.33997901364113325, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35257082896117525, 0.7, 'x[0] <= 11.612\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(0.3483735571878279, 0.66, 'x[1] <= 6.396\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.3441762854144806, 0.62, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.35257082896117525, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3567681007345226, 0.66, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.5919382869884575, 0.82, 'x[1] <= 11.902\ngini = 0.168\nsamples = 1040\nvalue = [944, 96]'),
#  Text(0.4611588405036726, 0.78, 'x[1] <= 8.162\ngini = 0.128\nsamples = 946\nvalue = [881, 65]'),
#  Text(0.3704092339979014, 0.74, 'x[0] <= 8.46\ngini = 0.421\nsamples = 63\nvalue = [44, 19]'),
#  Text(0.36621196222455404, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3746065057712487, 0.7, 'x[0] <= 10.63\ngini = 0.402\nsamples = 61\nvalue = [44, 17]'),
#  Text(0.3651626442812172, 0.66, 'x[1] <= 8.144\ngini = 0.251\nsamples = 34\nvalue = [29, 5]'),
#  Text(0.36096537250786986, 0.62, 'x[0] <= 9.544\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.3567681007345226, 0.58, 'x[0] <= 9.321\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.3462749213011542, 0.54, 'x[0] <= 8.694\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.3378803777544596, 0.5, 'x[1] <= 7.691\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3336831059811123, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34207764952780695, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3546694648478489, 0.5, 'x[1] <= 7.052\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.35047219307450156, 0.46, 'x[1] <= 7.021\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3462749213011542, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3546694648478489, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3588667366211962, 0.46, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3672612801678909, 0.54, 'x[1] <= 7.497\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.36306400839454356, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.37145855194123817, 0.5, 'x[1] <= 7.772\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3672612801678909, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3756558237145855, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3651626442812172, 0.58, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.36935991605456453, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38405036726128017, 0.66, 'x[0] <= 10.743\ngini = 0.494\nsamples = 27\nvalue = [15, 12]'),
#  Text(0.37985309548793283, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3882476390346275, 0.62, 'x[1] <= 7.071\ngini = 0.48\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.38405036726128017, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.39244491080797483, 0.58, 'x[0] <= 11.082\ngini = 0.469\nsamples = 24\nvalue = [15, 9]'),
#  Text(0.38405036726128017, 0.54, 'x[0] <= 10.872\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.37985309548793283, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3882476390346275, 0.5, 'x[1] <= 7.117\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.38405036726128017, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39244491080797483, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.40083945435466944, 0.54, 'x[0] <= 11.45\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.39664218258132217, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4050367261280168, 0.5, 'x[0] <= 11.573\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.40083945435466944, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4092339979013641, 0.46, 'x[1] <= 8.098\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.4050367261280168, 0.42, 'x[1] <= 7.681\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.39664218258132217, 0.38, 'x[0] <= 12.442\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.39244491080797483, 0.34, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.40083945435466944, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41343126967471144, 0.38, 'x[1] <= 8.001\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.4092339979013641, 0.34, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4176285414480588, 0.34, 'x[1] <= 8.057\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.41343126967471144, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4218258132214061, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41343126967471144, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5519084470094439, 0.74, 'x[1] <= 11.286\ngini = 0.099\nsamples = 883\nvalue = [837, 46]'),
#  Text(0.4983604407135362, 0.7, 'x[0] <= 12.594\ngini = 0.08\nsamples = 791\nvalue = [758, 33]'),
#  Text(0.46865162644281216, 0.66, 'x[0] <= 8.386\ngini = 0.076\nsamples = 787\nvalue = [756, 31]'),
#  Text(0.4218258132214061, 0.62, 'x[1] <= 8.635\ngini = 0.271\nsamples = 31\nvalue = [26, 5]'),
#  Text(0.41343126967471144, 0.58, 'x[1] <= 8.43\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4092339979013641, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4176285414480588, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4302203567681007, 0.58, 'x[0] <= 8.376\ngini = 0.191\nsamples = 28\nvalue = [25, 3]'),
#  Text(0.4260230849947534, 0.54, 'x[1] <= 10.383\ngini = 0.137\nsamples = 27\nvalue = [25, 2]'),
#  Text(0.4218258132214061, 0.5, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.4302203567681007, 0.5, 'x[1] <= 10.45\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.4260230849947534, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.43441762854144805, 0.46, 'x[0] <= 8.272\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.4302203567681007, 0.42, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4386149003147954, 0.42, 'x[0] <= 8.323\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.43441762854144805, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4428121720881427, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.43441762854144805, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5154774396642182, 0.62, 'x[0] <= 11.595\ngini = 0.066\nsamples = 756\nvalue = [730, 26]'),
#  Text(0.4947534102833158, 0.58, 'x[0] <= 9.799\ngini = 0.058\nsamples = 702\nvalue = [681, 21]'),
#  Text(0.472193074501574, 0.54, 'x[0] <= 9.794\ngini = 0.094\nsamples = 284\nvalue = [270.0, 14.0]'),
#  Text(0.46799580272822666, 0.5, 'x[1] <= 10.361\ngini = 0.088\nsamples = 283\nvalue = [270, 13]'),
#  Text(0.459601259181532, 0.46, 'x[1] <= 10.359\ngini = 0.116\nsamples = 194\nvalue = [182, 12]'),
#  Text(0.45540398740818466, 0.42, 'x[0] <= 8.77\ngini = 0.107\nsamples = 193\nvalue = [182, 11]'),
#  Text(0.45120671563483733, 0.38, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.459601259181532, 0.38, 'x[0] <= 8.795\ngini = 0.124\nsamples = 165\nvalue = [154, 11]'),
#  Text(0.45540398740818466, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.46379853095487933, 0.34, 'x[1] <= 9.98\ngini = 0.115\nsamples = 164\nvalue = [154, 10]'),
#  Text(0.459601259181532, 0.3, 'x[1] <= 9.971\ngini = 0.142\nsamples = 130\nvalue = [120, 10]'),
#  Text(0.45540398740818466, 0.26, 'x[1] <= 9.637\ngini = 0.13\nsamples = 129\nvalue = [120, 9]'),
#  Text(0.43126967471143757, 0.22, 'x[1] <= 8.608\ngini = 0.088\nsamples = 87\nvalue = [83, 4]'),
#  Text(0.42077649527806926, 0.18, 'x[0] <= 9.744\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.41657922350472193, 0.14, 'x[0] <= 9.639\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.4123819517313746, 0.1, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.42077649527806926, 0.1, 'x[1] <= 8.51\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.41657922350472193, 0.06, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4249737670514166, 0.06, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4249737670514166, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.44176285414480587, 0.18, 'x[0] <= 8.987\ngini = 0.056\nsamples = 69\nvalue = [67, 2]'),
#  Text(0.4333683105981112, 0.14, 'x[0] <= 8.964\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.42917103882476393, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.43756558237145854, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45015739769150054, 0.14, 'x[1] <= 9.324\ngini = 0.031\nsamples = 64\nvalue = [63, 1]'),
#  Text(0.4459601259181532, 0.1, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.45435466946484787, 0.1, 'x[1] <= 9.332\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(0.45015739769150054, 0.06, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.45855194123819515, 0.06, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.4795383001049318, 0.22, 'x[1] <= 9.647\ngini = 0.21\nsamples = 42\nvalue = [37, 5]'),
#  Text(0.4753410283315845, 0.18, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4837355718782791, 0.18, 'x[0] <= 9.438\ngini = 0.139\nsamples = 40\nvalue = [37, 3]'),
#  Text(0.4753410283315845, 0.14, 'x[0] <= 8.962\ngini = 0.069\nsamples = 28\nvalue = [27, 1]'),
#  Text(0.47114375655823715, 0.1, 'x[0] <= 8.948\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.4669464847848898, 0.06, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4753410283315845, 0.06, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4795383001049318, 0.1, 'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(0.49213011542497376, 0.14, 'x[0] <= 9.451\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.4879328436516264, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4963273871983211, 0.1, 'x[1] <= 9.72\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.49213011542497376, 0.06, 'x[1] <= 9.684\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4879328436516264, 0.02, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4963273871983211, 0.02, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5005246589716684, 0.06, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.46379853095487933, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.46799580272822666, 0.3, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(0.46379853095487933, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.47639034627492133, 0.46, 'x[0] <= 8.676\ngini = 0.022\nsamples = 89\nvalue = [88, 1]'),
#  Text(0.472193074501574, 0.42, 'x[0] <= 8.654\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.46799580272822666, 0.38, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.47639034627492133, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4805876180482686, 0.42, 'gini = 0.0\nsamples = 77\nvalue = [77, 0]'),
#  Text(0.47639034627492133, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5173137460650578, 0.54, 'x[1] <= 10.296\ngini = 0.033\nsamples = 418\nvalue = [411, 7]'),
#  Text(0.5131164742917104, 0.5, 'x[1] <= 10.29\ngini = 0.049\nsamples = 281\nvalue = [274, 7]'),
#  Text(0.5089192025183631, 0.46, 'x[1] <= 9.998\ngini = 0.042\nsamples = 280\nvalue = [274, 6]'),
#  Text(0.5005246589716684, 0.42, 'x[0] <= 10.57\ngini = 0.026\nsamples = 226\nvalue = [223, 3]'),
#  Text(0.4963273871983211, 0.38, 'x[0] <= 10.557\ngini = 0.043\nsamples = 138\nvalue = [135, 3]'),
#  Text(0.49213011542497376, 0.34, 'x[0] <= 10.178\ngini = 0.029\nsamples = 137\nvalue = [135, 2]'),
#  Text(0.4879328436516264, 0.3, 'gini = 0.0\nsamples = 72\nvalue = [72, 0]'),
#  Text(0.4963273871983211, 0.3, 'x[0] <= 10.18\ngini = 0.06\nsamples = 65\nvalue = [63, 2]'),
#  Text(0.49213011542497376, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5005246589716684, 0.26, 'x[0] <= 10.239\ngini = 0.031\nsamples = 64\nvalue = [63, 1]'),
#  Text(0.4963273871983211, 0.22, 'x[0] <= 10.234\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.49213011542497376, 0.18, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.5005246589716684, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5047219307450157, 0.22, 'gini = 0.0\nsamples = 53\nvalue = [53, 0]'),
#  Text(0.5005246589716684, 0.34, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5047219307450157, 0.38, 'gini = 0.0\nsamples = 88\nvalue = [88, 0]'),
#  Text(0.5173137460650578, 0.42, 'x[1] <= 10.008\ngini = 0.105\nsamples = 54\nvalue = [51, 3]'),
#  Text(0.5131164742917104, 0.38, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.521511017838405, 0.38, 'x[1] <= 10.028\ngini = 0.073\nsamples = 53\nvalue = [51, 2]'),
#  Text(0.5131164742917104, 0.34, 'x[1] <= 10.023\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.5089192025183631, 0.3, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5173137460650578, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5299055613850997, 0.34, 'x[0] <= 10.76\ngini = 0.043\nsamples = 45\nvalue = [44, 1]'),
#  Text(0.5257082896117523, 0.3, 'gini = 0.0\nsamples = 33\nvalue = [33, 0]'),
#  Text(0.534102833158447, 0.3, 'x[0] <= 10.924\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.5299055613850997, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5383001049317944, 0.26, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.5173137460650578, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.521511017838405, 0.5, 'gini = 0.0\nsamples = 137\nvalue = [137, 0]'),
#  Text(0.5362014690451207, 0.58, 'x[0] <= 11.604\ngini = 0.168\nsamples = 54\nvalue = [49, 5]'),
#  Text(0.5320041972717734, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.540398740818468, 0.54, 'x[1] <= 8.75\ngini = 0.14\nsamples = 53\nvalue = [49, 4]'),
#  Text(0.5299055613850997, 0.5, 'x[1] <= 8.623\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5257082896117523, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.534102833158447, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5508919202518363, 0.5, 'x[0] <= 11.615\ngini = 0.111\nsamples = 51\nvalue = [48, 3]'),
#  Text(0.5424973767051416, 0.46, 'x[0] <= 11.614\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5383001049317944, 0.42, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.546694648478489, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.559286463798531, 0.46, 'x[1] <= 10.182\ngini = 0.08\nsamples = 48\nvalue = [46, 2]'),
#  Text(0.5550891920251836, 0.42, 'gini = 0.0\nsamples = 29\nvalue = [29, 0]'),
#  Text(0.5634837355718783, 0.42, 'x[1] <= 10.334\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(0.559286463798531, 0.38, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5676810073452256, 0.38, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.5280692549842603, 0.66, 'x[0] <= 12.638\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.5238719832109129, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5322665267576075, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6054564533053515, 0.7, 'x[0] <= 10.721\ngini = 0.243\nsamples = 92\nvalue = [79.0, 13.0]'),
#  Text(0.5844700944386149, 0.66, 'x[1] <= 11.313\ngini = 0.131\nsamples = 71\nvalue = [66, 5]'),
#  Text(0.5802728226652676, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5886673662119623, 0.62, 'x[0] <= 8.902\ngini = 0.083\nsamples = 69\nvalue = [66, 3]'),
#  Text(0.5802728226652676, 0.58, 'x[0] <= 8.892\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.5760755508919203, 0.54, 'x[0] <= 8.443\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.5718782791185729, 0.5, 'x[0] <= 8.354\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5676810073452256, 0.46, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5760755508919203, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5802728226652676, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.5844700944386149, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5970619097586569, 0.58, 'x[1] <= 11.466\ngini = 0.036\nsamples = 55\nvalue = [54, 1]'),
#  Text(0.5928646379853095, 0.54, 'x[1] <= 11.454\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.5886673662119623, 0.5, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.5970619097586569, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6012591815320042, 0.54, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(0.6264428121720882, 0.66, 'x[1] <= 11.768\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.6222455403987408, 0.62, 'x[1] <= 11.398\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.6138509968520461, 0.58, 'x[1] <= 11.333\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.6096537250786989, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6180482686253935, 0.54, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6306400839454355, 0.58, 'x[0] <= 11.202\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.6264428121720882, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6348373557187827, 0.54, 'x[1] <= 11.574\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.6264428121720882, 0.5, 'x[1] <= 11.514\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.6222455403987408, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6306400839454355, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6432318992654774, 0.5, 'x[1] <= 11.68\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6390346274921301, 0.46, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6474291710388248, 0.46, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6306400839454355, 0.62, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7227177334732424, 0.78, 'x[1] <= 12.852\ngini = 0.442\nsamples = 94\nvalue = [63.0, 31.0]'),
#  Text(0.6852046169989506, 0.74, 'x[1] <= 12.132\ngini = 0.361\nsamples = 55\nvalue = [42, 13]'),
#  Text(0.6684155299055614, 0.7, 'x[0] <= 11.713\ngini = 0.484\nsamples = 17\nvalue = [10, 7]'),
#  Text(0.664218258132214, 0.66, 'x[1] <= 12.097\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.6600209863588667, 0.62, 'x[1] <= 11.926\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.6516264428121721, 0.58, 'x[1] <= 11.907\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6474291710388248, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6558237145855194, 0.54, 'x[0] <= 9.791\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6516264428121721, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6600209863588667, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6684155299055614, 0.58, 'x[0] <= 11.195\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.664218258132214, 0.54, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.6726128016789087, 0.54, 'x[1] <= 12.009\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6684155299055614, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6768100734522561, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6684155299055614, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6726128016789087, 0.66, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.70199370409234, 0.7, 'x[0] <= 9.571\ngini = 0.266\nsamples = 38\nvalue = [32, 6]'),
#  Text(0.6935991605456453, 0.66, 'x[0] <= 9.492\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.689401888772298, 0.62, 'x[1] <= 12.473\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.6852046169989506, 0.58, 'x[1] <= 12.28\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.6810073452256034, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.689401888772298, 0.54, 'x[0] <= 8.238\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6852046169989506, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6935991605456453, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6935991605456453, 0.58, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6977964323189927, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7103882476390346, 0.66, 'x[0] <= 11.352\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.7061909758656874, 0.62, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(0.7145855194123819, 0.62, 'x[0] <= 11.495\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.7103882476390346, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7187827911857293, 0.58, 'x[0] <= 12.086\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.7145855194123819, 0.54, 'x[0] <= 11.981\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7103882476390346, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7187827911857293, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7229800629590766, 0.54, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7602308499475341, 0.74, 'x[1] <= 14.2\ngini = 0.497\nsamples = 39\nvalue = [21, 18]'),
#  Text(0.74501573976915, 0.7, 'x[0] <= 9.333\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.727177334732424, 0.66, 'x[1] <= 13.911\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.7229800629590766, 0.62, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.7313746065057712, 0.62, 'x[1] <= 14.079\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.727177334732424, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7355718782791185, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7628541448058762, 0.66, 'x[1] <= 13.862\ngini = 0.499\nsamples = 19\nvalue = [10, 9]'),
#  Text(0.7523609653725079, 0.62, 'x[0] <= 12.056\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.7439664218258132, 0.58, 'x[0] <= 10.748\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.7397691500524659, 0.54, 'x[0] <= 9.921\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7355718782791185, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7439664218258132, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7481636935991606, 0.54, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.7607555089192025, 0.58, 'x[0] <= 12.531\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.7565582371458552, 0.54, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.7649527806925498, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7733473242392445, 0.62, 'x[0] <= 9.98\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.7691500524658972, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7775445960125918, 0.58, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7754459601259182, 0.7, 'x[0] <= 12.355\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.7712486883525709, 0.66, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.7796432318992654, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8027282266526757, 0.86, 'x[1] <= 15.411\ngini = 0.127\nsamples = 88\nvalue = [6, 82]'),
#  Text(0.7922350472193075, 0.82, 'x[0] <= 9.069\ngini = 0.401\nsamples = 18\nvalue = [5, 13]'),
#  Text(0.7838405036726128, 0.78, 'x[1] <= 14.571\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.7796432318992654, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7880377754459601, 0.74, 'x[0] <= 8.976\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.7838405036726128, 0.7, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7922350472193075, 0.7, 'x[1] <= 15.182\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7880377754459601, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7964323189926548, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8006295907660022, 0.78, 'x[0] <= 12.222\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.7964323189926548, 0.74, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.8048268625393494, 0.74, 'x[0] <= 12.46\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.8006295907660022, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8090241343126967, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8132214060860441, 0.82, 'x[1] <= 18.949\ngini = 0.028\nsamples = 70\nvalue = [1, 69]'),
#  Text(0.8090241343126967, 0.78, 'gini = 0.0\nsamples = 55\nvalue = [0, 55]'),
#  Text(0.8174186778593914, 0.78, 'x[1] <= 18.981\ngini = 0.124\nsamples = 15\nvalue = [1, 14]'),
#  Text(0.8132214060860441, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8216159496327388, 0.74, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.9406151626442812, 0.94, 'x[0] <= 16.31\ngini = 0.176\nsamples = 442\nvalue = [43, 399]'),
#  Text(0.7938620536299843, 0.96, '  False'),
#  Text(0.9064139559286464, 0.9, 'x[1] <= 5.252\ngini = 0.265\nsamples = 255\nvalue = [40, 215]'),
#  Text(0.9022166841552991, 0.86, 'gini = 0.0\nsamples = 61\nvalue = [0, 61]'),
#  Text(0.9106112277019937, 0.86, 'x[1] <= 14.426\ngini = 0.327\nsamples = 194\nvalue = [40, 154]'),
#  Text(0.8652938090241343, 0.82, 'x[0] <= 13.184\ngini = 0.416\nsamples = 122\nvalue = [36, 86]'),
#  Text(0.838405036726128, 0.78, 'x[1] <= 11.097\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.8300104931794333, 0.74, 'x[0] <= 13.136\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.825813221406086, 0.7, 'x[1] <= 9.47\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8216159496327388, 0.66, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8300104931794333, 0.66, 'x[1] <= 9.997\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.825813221406086, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8342077649527807, 0.62, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8342077649527807, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8467995802728226, 0.74, 'x[0] <= 12.89\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.8426023084994754, 0.7, 'x[0] <= 12.825\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.838405036726128, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8467995802728226, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.85099685204617, 0.7, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8921825813221406, 0.78, 'x[0] <= 15.857\ngini = 0.384\nsamples = 108\nvalue = [28, 80]'),
#  Text(0.8725078698845751, 0.74, 'x[1] <= 14.333\ngini = 0.352\nsamples = 92\nvalue = [21, 71]'),
#  Text(0.8683105981112277, 0.7, 'x[1] <= 6.707\ngini = 0.343\nsamples = 91\nvalue = [20, 71]'),
#  Text(0.8551941238195173, 0.66, 'x[0] <= 13.335\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.85099685204617, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8593913955928646, 0.62, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.881427072402938, 0.66, 'x[0] <= 13.567\ngini = 0.378\nsamples = 75\nvalue = [19, 56]'),
#  Text(0.8677859391395593, 0.62, 'x[1] <= 9.312\ngini = 0.18\nsamples = 20\nvalue = [2, 18]'),
#  Text(0.863588667366212, 0.58, 'x[1] <= 8.853\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.8593913955928646, 0.54, 'x[0] <= 13.292\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.8551941238195173, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.863588667366212, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8677859391395593, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8719832109129066, 0.58, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.8950682056663168, 0.62, 'x[0] <= 15.613\ngini = 0.427\nsamples = 55\nvalue = [17, 38]'),
#  Text(0.8908709338929696, 0.58, 'x[0] <= 15.395\ngini = 0.453\nsamples = 49\nvalue = [17.0, 32.0]'),
#  Text(0.8803777544596013, 0.54, 'x[0] <= 15.034\ngini = 0.429\nsamples = 45\nvalue = [14, 31]'),
#  Text(0.8719832109129066, 0.5, 'x[0] <= 14.843\ngini = 0.472\nsamples = 34\nvalue = [13, 21]'),
#  Text(0.8677859391395593, 0.46, 'x[1] <= 13.109\ngini = 0.451\nsamples = 32\nvalue = [11, 21]'),
#  Text(0.863588667366212, 0.42, 'x[0] <= 13.897\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.8488982161594963, 0.38, 'x[1] <= 8.893\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.844700944386149, 0.34, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8530954879328436, 0.34, 'x[0] <= 13.843\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8488982161594963, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.857292759706191, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8782791185729276, 0.38, 'x[1] <= 12.508\ngini = 0.42\nsamples = 20\nvalue = [6, 14]'),
#  Text(0.869884575026233, 0.34, 'x[0] <= 14.209\ngini = 0.305\nsamples = 16\nvalue = [3, 13]'),
#  Text(0.8656873032528857, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8740818467995802, 0.3, 'x[0] <= 14.226\ngini = 0.397\nsamples = 11\nvalue = [3, 8]'),
#  Text(0.869884575026233, 0.26, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8782791185729276, 0.26, 'x[0] <= 14.721\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.869884575026233, 0.22, 'x[1] <= 9.96\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.8656873032528857, 0.18, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8740818467995802, 0.18, 'x[0] <= 14.462\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.869884575026233, 0.14, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8782791185729276, 0.14, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8866736621196223, 0.22, 'x[0] <= 14.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8824763903462749, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8908709338929696, 0.18, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8866736621196223, 0.34, 'x[0] <= 14.108\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8824763903462749, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8908709338929696, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8719832109129066, 0.42, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8761804826862539, 0.46, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8887722980062959, 0.5, 'x[1] <= 12.535\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.8845750262329486, 0.46, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.8929695697796433, 0.46, 'x[1] <= 13.604\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8887722980062959, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8971668415529905, 0.42, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9013641133263379, 0.54, 'x[1] <= 8.099\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8971668415529905, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9055613850996852, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8992654774396642, 0.58, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.8767051416579223, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9118572927597062, 0.74, 'x[1] <= 8.587\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.9034627492130115, 0.7, 'x[0] <= 16.003\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.8992654774396642, 0.66, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9076600209863589, 0.66, 'x[0] <= 16.051\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.9034627492130115, 0.62, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9118572927597062, 0.62, 'x[0] <= 16.094\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.9076600209863589, 0.58, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9160545645330536, 0.58, 'x[1] <= 6.585\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9118572927597062, 0.54, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9202518363064008, 0.54, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9202518363064008, 0.7, 'x[0] <= 16.281\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.9160545645330536, 0.66, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9244491080797481, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9559286463798531, 0.82, 'x[0] <= 13.229\ngini = 0.105\nsamples = 72\nvalue = [4, 68]'),
#  Text(0.9454354669464848, 0.78, 'x[0] <= 13.198\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.9412381951731374, 0.74, 'x[1] <= 16.333\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.9370409233997902, 0.7, 'x[1] <= 16.151\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.9328436516264428, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9412381951731374, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9454354669464848, 0.7, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.9496327387198321, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9664218258132214, 0.78, 'x[1] <= 19.328\ngini = 0.064\nsamples = 60\nvalue = [2, 58]'),
#  Text(0.9580272822665268, 0.74, 'x[1] <= 15.116\ngini = 0.034\nsamples = 57\nvalue = [1, 56]'),
#  Text(0.9538300104931794, 0.7, 'x[1] <= 15.039\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.9496327387198321, 0.66, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.9580272822665268, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9622245540398741, 0.7, 'gini = 0.0\nsamples = 50\nvalue = [0, 50]'),
#  Text(0.974816369359916, 0.74, 'x[1] <= 19.464\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.9706190975865687, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9790136411332634, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.974816369359916, 0.9, 'x[1] <= 6.461\ngini = 0.032\nsamples = 187\nvalue = [3.0, 184.0]'),
#  Text(0.9706190975865687, 0.86, 'gini = 0.0\nsamples = 69\nvalue = [0, 69]'),
#  Text(0.9790136411332634, 0.86, 'x[1] <= 6.686\ngini = 0.05\nsamples = 118\nvalue = [3, 115]'),
#  Text(0.974816369359916, 0.82, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9832109129066107, 0.82, 'x[1] <= 12.308\ngini = 0.034\nsamples = 117\nvalue = [2, 115]'),
#  Text(0.9790136411332634, 0.78, 'gini = 0.0\nsamples = 57\nvalue = [0, 57]'),
#  Text(0.9874081846799581, 0.78, 'x[1] <= 12.46\ngini = 0.064\nsamples = 60\nvalue = [2, 58]'),
#  Text(0.9832109129066107, 0.74, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9916054564533053, 0.74, 'x[1] <= 13.758\ngini = 0.033\nsamples = 59\nvalue = [1, 58]'),
#  Text(0.9874081846799581, 0.7, 'x[1] <= 13.734\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.9832109129066107, 0.66, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.9916054564533053, 0.66, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9958027282266527, 0.7, 'gini = 0.0\nsamples = 45\nvalue = [0, 45]')]

# %% [markdown]
# **Coding Exersice:** Perform sensitivity analysis over over $\textit{'max_depth'} $ hyperparameter for both training and test errors in the same figure. You need to calculate the errors for both sets.

# %%
# Define the range of max_depth values to test
max_depth_values = range(1, 21)  # Test max_depth from 1 to 20

# Initialize lists to store training and test errors
training_errors = []
test_errors = []

# Split the dataset into training and testing sets with 20% test and 80% training
#You code starts here

#Your code ends here

# Iterate over each max_depth value
#You code starts here
for max_depth in max_depth_values:
    # Train a decision tree classifier with the current max_depth value


    # Evaluate the classifier on the training set


    # Evaluate the classifier on the test set

#Your code ends here

# Plot the sensitivity analysis results

plt.figure(figsize=(10, 6))
#You code starts here

#Your code ends here
plt.title('Sensitivity Analysis over Max Depth')
plt.xlabel('Max Depth')
plt.ylabel('Classification Error')
plt.xticks(max_depth_values)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Coding Exersice:** Re-train the decision tree with $\textit{'max_depth'} $ of 20. Show the accuracy results for both training and test sets.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split the dataset into training and testing sets with 20% test and 80% training
#You code starts here

#Your code ends here

# Train a decision tree classifier with a maximum depth of 20
#You code starts here

#Your code ends here

# Evaluate the classifier on the training set
#You code starts here

#Your code ends here

# Evaluate the classifier on the testing set
#You code starts here

#Your code ends here

# %% [markdown]
# **Question:** Do you see any gap between the accuracies of the training and test sets? If yes, what is the cause of this difference? Explain.
#
# **Answer:** Your answer goes here!

# %% [markdown]
# **Coding Exersice:** Re-train the decision tree with $\textit{'max_depth'} $ of 4. Show the accuracy results for both training and test sets.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split the dataset into training and testing sets with 20% test and 80% training
#You code starts here

#You code ends here

# Train a decision tree classifier with a maximum depth of 4
#You code starts here

#You code ends here

# Evaluate the classifier on the training set
#You code starts here

#You code ends here

# Evaluate the classifier on the testing set
#You code starts here

#You code ends here

# %% [markdown]
# **Question:** How is the gap now? Is your test set accuracy better? why is that? Explain.
#
# **Answer:** Your answer goes here!

# %% [markdown]
# **Post-Pruning:** To apply post-pruning to the decision tree with 'max_depth' of 20, you can use the ccp_alpha parameter, which stands for Complexity Cost Pruning. This parameter controls the threshold for pruning. As the threshold increases, more nodes are pruned, leading to a simpler tree.
#
# Here's how you can apply post-pruning with a maximum size of 20 using the DecisionTreeClassifier in scikit-learn:

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Split the dataset into training and testing sets with 20% test and 80% training
#You code starts here

#You code ends here

# Train a decision tree classifier with a maximum size of 20
""" You can use the same code as before. You have already trained this model."""
#You code starts here

#You code ends here

# Apply post-pruning with different ccp_alpha values
""" use tree_clf.cost_complexity_pruning_path , then capture ccp_alphas """
#You code starts here

#You code ends here

# Initialize lists to store accuracy scores
accuracy_scores = []

# Iterate over different ccp_alpha values and retrain the decision tree and print out the accuracy of the retrained model
#You code starts here
for ccp_alpha in ccp_alphas:

    print(f"Accuracy for ccp_alpha={ccp_alpha}: {accuracy_pruned}")
#You code ends here

# %% [markdown]
# **Question:** How the accuracy is changing with respect to different values of 'ccp_alpha'? What is the best accuracy you get? Isn't that close to the accuracy you had for 'max_depth' of 4 ? why this happened (i.e., accuracy imporved for the model with 'max_depth' of 20 after post-pruning)?
#
# **Answer:** Your answer goes here!
